# %% [markdown]
# # Challenge 3: Artificial Neural Networks
#
# <a target="_blank" href="https://colab.research.google.com/github/LucaPennella/Intro_to_ML_23-24/blob/main/challenges/challenge-three.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
#
# Using Fully Connected Neural Networks and Convolutional Neural Networks, perform the following tasks on [this data set](https://pytorch.org/vision/stable/generated/torchvision.datasets.KMNIST.html#torchvision.datasets.KMNIST).
# 1. Data exploration.
# 2. For each architecture, tune the number of the hidden layers ($\le 3$), the optimizer, and some hyperparameters of your choice. How many tries to do is up to your discretion.
# 3. Summarise your results in a table and comment on them in the report.
# 4. For a model (not necessarily the best performing one), plot training loss vs testing loss and training accuracy vs testing accuracy, and comment on what you see.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
np.random.seed(64)
random.seed(64)

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from time import time
torch.manual_seed(64)

# %% [markdown]
# ## Data exploration

# %%
BATCH_SIZE = 64

data_transforms = transforms.ToTensor()

# TRAIN set
trainset = torchvision.datasets.KMNIST(root='./data', train=True, download=True, transform=data_transforms)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
print(len(trainset))

# TEST set
testset = torchvision.datasets.KMNIST(root='./data', train=False, download=True, transform=data_transforms)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)
print(len(testset))
# Out:
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz to ./data/KMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 18165135/18165135 [00:04<00:00, 4132305.77it/s]
# Extracting ./data/KMNIST/raw/train-images-idx3-ubyte.gz to ./data/KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz to ./data/KMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29497/29497 [00:00<00:00, 882027.74it/s]
# Extracting ./data/KMNIST/raw/train-labels-idx1-ubyte.gz to ./data/KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz to ./data/KMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 3041136/3041136 [00:01<00:00, 2976859.24it/s]
# Extracting ./data/KMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/KMNIST/raw
#
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz to ./data/KMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5120/5120 [00:00<00:00, 24237964.42it/s]
# Extracting ./data/KMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/KMNIST/raw
# 60000
# 10000

# %%
num_row = 2
num_col = 5

classes = trainset.classes

fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col, 2*num_row))
for i in range(num_row*num_col):
    ax = axes[i//num_col, i%num_col]
    ax.imshow(trainset.data[i], cmap='gray')
    ax.set_title('Label: {}'.format(classes[trainset.targets[i]]))
plt.tight_layout()
plt.show()

print(f'Classes: {classes}')
# Out:
# Classes: ['o', 'ki', 'su', 'tsu', 'na', 'ha', 'ma', 'ya', 're', 'wo']

# %%
# printing data shapes
print("Single image dimensions:", trainset.data[0].shape)
for images, labels in trainloader:
    print("Image batch dimensions:", images.shape)
    print("Image label dimensions:", labels.shape)
    break
# Out:
# Single image dimensions: torch.Size([28, 28])
# Image batch dimensions: torch.Size([64, 1, 28, 28])
# Image label dimensions: torch.Size([64])

# %% [markdown]
# The data comes from the KMNIST dataset and it consists of consists of 70000 28x28 pixel, 1 channel images of hiragana symbols; 60000 are reserved for the training set and 10000 for the test set. The symbols are grouped in 10 classes

# %% [markdown]
# ## Model building

# %% [markdown]
# 2. For each architecture, tune the number of the hidden layers ($\le 3$), the optimizer, and some hyperparameters of your choice. How many tries to do is up to your discretion.

# %% [markdown]
# We chose to implement three models: a FCNN with 1 hidden layer, a CNN with 1 hidden layer, and a CNN with 3 hidden layers.

# %% [markdown]
# #### FULLY CONNECTED

# %%
class FullyConnected_1(nn.Module):

    def __init__(self):
        super(FullyConnected_1, self).__init__()

        self.l1 = nn.Linear(28 * 28, 32 * 26 * 26)  # Input size: 28*28
        self.l2 = nn.Linear(32 * 26 * 26, 128)
        self.l3 = nn.Linear(128, 10)


    def forward(self, x):

        x = x.flatten(start_dim = 1)    # flatten: BSx1x28x28 => BSx784

        x = self.l1(x)                  # Linear: BSx784 => BSx21632
        x = F.relu(x)

        x = self.l2(x)                  # Linear: BSx21632 => BSx128
        x = F.relu(x)

        logits = self.l3(x)             # Linear: BSx128 => BSx10

        out = F.softmax(logits, dim=1)  # Softmax computation

        return out

# %% [markdown]
# #### CONVOLUTIONAL

# %% [markdown]
# 1 hidden layer

# %%
class Convolutional_1(nn.Module):

    def __init__(self):
        super(Convolutional_1, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=5)   # 28 - kernel_size +1 = 24
        # max-pooling 2x2: 24 / 2 = 12
        self.l1 = nn.Linear(32 * 12 * 12, 128)
        self.l2 = nn.Linear(128, 10)


    def forward(self, x):

        x = self.conv1(x)               # Convolution: BSx1x28x28 => BSx32x24x24
        x = F.relu(x)

        x = F.max_pool2d(x,2)           # Max-pooling 2x2 => BSx32x12x12

        x = x.flatten(start_dim = 1)    # flatten => BS x 4608

        x = self.l1(x)                  # Linear: BSx(32*12*12) => BSx128
        x = F.relu(x)

        logits = self.l2(x)             # Linear: BSx128 => BSx10

        out = F.softmax(logits, dim=1)  # Softmax computation

        return out

# %% [markdown]
# 3 hidden layers

# %%
class Convolutional_3(nn.Module):

    def __init__(self):
        super(Convolutional_3, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=5)       # 28 - kernel_size +1 = 24
        # max-pooling 2x2: 24 / 2 = 12
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=128, kernel_size=3)     # 12 - kernel_size +1 = 10
        # max-pooling 2x2: 10 / 2 = 5
        self.l1 = nn.Linear(128 * 5 * 5, 256)
        self.l2 = nn.Linear(256, 64)
        self.l3 = nn.Linear(64, 10)


    def forward(self, x):

        x = self.conv1(x)               # Convolution: BSx1x28x28 => BSx32x24x24
        x = F.relu(x)

        x = F.max_pool2d(x,2)           # Max-pooling 2x2 => BSx32x12x12

        x = self.conv2(x)               # Convolution: BSx32x12x12 => BSx128x10x10
        x = F.relu(x)

        x = F.max_pool2d(x,2)           # Max-pooling 2x2 => BSx128x5x5

        x = x.flatten(start_dim = 1)    # flatten => BS x 3200

        x = self.l1(x)                  # Linear: BSx(128*5*5) => BSx256
        x = F.relu(x)

        x = self.l2(x)                  # Linear: BSx256 => BSx64
        x = F.relu(x)

        logits = self.l3(x)             # Linear: BSx64 => BSx10

        out = F.softmax(logits, dim=1)  # Softmax computation

        return out

# %% [markdown]
# #### Training cycle

# %%
def get_accuracy(logit, target):
    corrects = (torch.max(logit, 1)[1].view(target.size()).data == target.data).sum()   # correct predictions
    accuracy = 100.0 * corrects / target.size(0)                                        # % of correct predictions
    return accuracy.item()


def compute_weight_norm(model):     # extracting the weight norms
    norm = 0.0
    for name, param in model.named_parameters():
        if "weight" in name:
            norm += torch.norm(param.data, p=2)
    return norm.cpu().item()


def train_model(model, num_epochs, trainloader, criterion, optimizer, device):

    print(f'Training model: {model.__class__.__name__} with Loss function: {criterion} and Optimizer: {optimizer.__class__.__name__}\n')

    model = model.to(device)

    losses = []
    accs = []

    norms = []

    for epoch in range(num_epochs):
        train_running_loss = 0.0
        train_acc = 0.0

        # Set the model to training mode
        model = model.train()
        start = time()
        ## training step
        for i, (images, labels) in enumerate(trainloader):

            images = images.to(device)
            labels = labels.to(device)

            ## forward + backprop + loss
            logits = model(images)
            loss = criterion(logits, labels)

            # Reset the gradients to zero
            optimizer.zero_grad()

            loss.backward()

            ## update model params
            optimizer.step()

            train_running_loss += loss.item()
            train_acc += get_accuracy(logits, labels)


        losses.append(train_running_loss / i)
        accs.append(train_acc/i)

        norms.append(compute_weight_norm(model))
        model.eval()
        print(f"\tEpoch: [{epoch+1}/{num_epochs}] | Loss: {train_running_loss / i:.4f} | Train Accuracy: {train_acc/i:.4f} | Time: {time()-start:.2f}")

    print('\n')
    return losses, accs, norms

# %%
num_epochs = 10
num_models = 3*2    # 3 models, 2 optimizers
learning_rates = [0.00001, 0.0001, 0.001, 0.01, 0.1, 0.5, 1, 3, 5]
criterion = nn.CrossEntropyLoss()   # loss function

losses = []
accuracies = []
weight_norms = []
optimizer_names = ['SGD', 'Adam']

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# We want to train our models with different learning rates
for lr in learning_rates:

    print('-'*90)
    print(f'Training with learning rate: {lr}')
    print(f'Using device: {device}' if device=='cpu' else f'Using device: {device} ({torch.cuda.get_device_name()})')
    print('-'*90)
    print()

    losses_lr = []
    accuracies_lr = []
    weight_norms_lr = []

    # Training each model-optimizer pair
    for model_index in range(0, num_models, 2):

        # re-initiliazing our models for every optimizer
        models = [FullyConnected_1(), FullyConnected_1(), Convolutional_1(), Convolutional_1(), Convolutional_3(), Convolutional_3()]

        loss_sgd, acc_sgd, W_sgd = train_model(models[model_index], num_epochs, trainloader, criterion, torch.optim.SGD(models[model_index].parameters(), lr=lr), device)
        loss_adam, acc_adam, W_adam = train_model(models[model_index+1], num_epochs, trainloader, criterion, torch.optim.Adam(models[model_index+1].parameters(), lr=lr), device)

        losses_lr.extend([loss_sgd, loss_adam])
        accuracies_lr.extend([acc_sgd, acc_adam])
        weight_norms_lr.extend([W_sgd, W_adam])

    losses.append(losses_lr)
    accuracies.append(accuracies_lr)
    weight_norms.append(weight_norms_lr)

    print()
# Out:
# ------------------------------------------------------------------------------------------
# Training with learning rate: 1e-05
# Using device: cuda (Tesla T4)
# ------------------------------------------------------------------------------------------
#
# Training model: FullyConnected_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/10] | Loss: 2.
#
# Training model: FullyConnected_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/10] | Loss: 2.0627 | Train Accuracy: 39.9080 | Time: 10.45
# 	Epoch: [2/10] | Loss: 2.3545 | Train Accuracy: 10.9258 | Time: 10.41
# 	Epoch: [3/10] | Loss: 2.3635 | Train Accuracy: 10.0253 | Time: 10.26
# 	Epoch: [4/10] | Loss: 2.3636 | Train Accuracy: 10.0187 | Time: 10.32
# 	Epoch: [5/10] | Loss: 2.3636 | Train Accuracy: 10.0187 | Time: 9.76
# 	Epoch: [6/10] | Loss: 2.3636 | Train Accuracy: 10.0220 | Time: 10.24
# 	Epoch: [7/10] | Loss: 2.3636 | Train Accuracy: 10.0220 | Time: 10.28
# 	Epoch: [8/10] | Loss: 2.3636 | Train Accuracy: 10.0187 | Time: 10.29
# 	Epoch: [9/10] | Loss: 2.3636 | Train Accuracy: 10.0170 | Time: 10.29
# 	Epoch: [10/10] | Loss: 2.3636 | Train Accuracy: 10.0153 | Time: 10.35
#
#
# Training model: FullyConnected_1 with Loss function: CrossEntropyLoss() and Optimizer: Adam
#
# 	Epoch: [1/10] | Loss: 2.3636 | Train Accuracy: 10.0087 | Time: 13.77
# 	Epoch: [2/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 13.75
# 	Epoch: [3/10] | Loss: 2.3637 | Train Accuracy: 10.0053 | Time: 13.75
# 	Epoch: [4/10] | Loss: 2.3637 | Train Accuracy: 10.0120 | Time: 14.10
# 	Epoch: [5/10] | Loss: 2.3637 | Train Accuracy: 10.0053 | Time: 13.71
# 	Epoch: [6/10] | Loss: 2.3637 | Train Accuracy: 10.0087 | Time: 13.82
# 	Epoch: [7/10] | Loss: 2.3637 | Train Accuracy: 10.0070 | Time: 14.04
# 	Epoch: [8/10] | Loss: 2.3636 | Train Accuracy: 10.0137 | Time: 13.69
# 	Epoch: [9/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 13.72
# 	Epoch: [10/10] | Loss: 2.3636 | Train Accuracy: 10.0137 | Time: 13.75
#
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/10] | Loss: 2.2774 | Train Accuracy: 18.5182 | Time: 7.97
# 	Epoch: [2/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 7.37
# 	Epoch: [3/10] | Loss: 2.3637 | Train Accuracy: 10.0070 | Time: 8.02
# 	Epoch: [4/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 8.03
# 	Epoch: [5/10] | Loss: 2.3637 | Train Accuracy: 10.0070 | Time: 7.34
# 	Epoch: [6/10] | Loss: 2.3637 | Train Accuracy: 10.0120 | Time: 8.84
# 	Epoch: [7/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 7.90
# 	Epoch: [8/10] | Loss: 2.3637 | Train Accuracy: 10.0070 | Time: 7.43
# 	Epoch: [9/10] | Loss: 2.3637 | Train Accuracy: 10.0120 | Time: 8.06
# 	Epoch: [10/10] | Loss: 2.3636 | Train Accuracy: 10.0137 | Time: 7.65
#
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: Adam
#
# 	Epoch: [1/10] | Loss: 2.3636 | Train Accuracy: 10.0153 | Time: 8.13
# 	Epoch: [2/10] | Loss: 2.3636 | Train Accuracy: 10.0137 | Time: 8.35
# 	Epoch: [3/10] | Loss: 2.3637 | Train Accuracy: 10.0053 | Time: 7.91
# 	Epoch: [5/10] | Loss: 2.3637 | Train Accuracy: 10.0070 | Time: 8.33
# 	Epoch: [6/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 7.89
# 	Epoch: [7/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 8.07
# 	Epoch: [8/10] | Loss: 2.3637 | Train Accuracy: 10.0087 | Time: 8.35
# 	Epoch: [9/10] | Loss: 2.3637 | Train Accuracy: 10.0087 | Time: 7.92
# 	Epoch: [10/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 8.06
#
#
# Training model: Convolutional_3 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/10] | Loss: 2.3581 | Train Accuracy: 10.4873 | Time: 9.27
# 	Epoch: [2/10] | Loss: 2.3637 | Train Accuracy: 10.0087 | Time: 9.32
# 	Epoch: [3/10] | Loss: 2.3637 | Train Accuracy: 10.0070 | Time: 8.72
# 	Epoch: [4/10] | Loss: 2.3636 | Train Accuracy: 10.0137 | Time: 9.23
# 	Epoch: [5/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 9.35
# 	Epoch: [6/10] | Loss: 2.3637 | Train Accuracy: 10.0087 | Time: 9.25
# 	Epoch: [7/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 9.59
# 	Epoch: [8/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 8.99
# 	Epoch: [9/10] | Loss: 2.3637 | Train Accuracy: 10.0087 | Time: 9.24
# 	Epoch: [10/10] | Loss: 2.3636 | Train Accuracy: 10.0137 | Time: 9.28
#
#
# Training model: Convolutional_3 with Loss function: CrossEntropyLoss() and Optimizer: Adam
#
# 	Epoch: [1/10] | Loss: 2.3636 | Train Accuracy: 10.0170 | Time: 9.40
# 	Epoch: [2/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 9.26
# 	Epoch: [3/10] | Loss: 2.3637 | Train Accuracy: 10.0120 | Time: 9.58
# 	Epoch: [4/10] | Loss: 2.3637 | Train Accuracy: 10.0053 | Time: 9.60
# 	Epoch: [5/10] | Loss: 2.3637 | Train Accuracy: 10.0087 | Time: 9.61
# 	Epoch: [6/10] | Loss: 2.3636 | Train Accuracy: 10.0153 | Time: 9.00
# 	Epoch: [7/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 9.60
# 	Epoch: [8/10] | Loss: 2.3637 | Train Accuracy: 10.0103 | Time: 9.63
# 	Epoch: [9/10] | Loss: 2.3637 | Train Accuracy: 10.0120 | Time: 9.65
# 	Epoch: [10/10] | Loss: 2.3637 | Train Accuracy: 10.0120 | Time: 9.50

# %% [markdown]
# ## Tables
# 3. Summarise your results in a table and comment on them in the report.

# %%
models_for_table = [[FullyConnected_1(), FullyConnected_1()], [Convolutional_1(), Convolutional_1()], [Convolutional_3(), Convolutional_3()]]
num_models = len(models_for_table)          # number of models: in this case, 3 (FullyConnected_1, Convolutional_1, Convolutional_3)
num_optimizers = len(optimizer_names)       # number of optimizers: in this case, 2 (SGD and Adam)
num_rows = num_epochs * num_models * num_optimizers

pd.set_option('display.max_columns', None)  # To display all columns
pd.set_option('display.max_rows', None)     # To display all rows

for lr_index, lr in enumerate(learning_rates):

    print(f'\nLearning rate: {lr}')

    table = pd.DataFrame({'Model' : [models_for_table[i][0].__class__.__name__ for i in range(num_models) for j in range(num_epochs*num_optimizers)],
            'Optimizer' : [optimizer_names[i] for k in range(num_models) for i in range(num_optimizers) for j in range(num_epochs)],
            'Epoch': [i % (num_epochs) + 1 for i in range(num_rows)],
            'Loss': [losses[lr_index][i][j] for i in range(num_models*num_optimizers) for j in range(num_epochs)],
            'Accuracy (train)': [accuracies[lr_index][i][j] for i in range(num_models*num_optimizers) for j in range(num_epochs)],
            })

    separator = pd.DataFrame({'Model' : ['---'],
            'Optimizer' : ['---'],
            'Epoch': ['---'],
            'Loss': ['---'],
            'Accuracy (train)': ['---'],
            })

    for i in range(num_optimizers*num_epochs, num_rows, num_optimizers*num_epochs+1):
        table = pd.concat([table.iloc[:i], separator, table.iloc[i:]]).reset_index(drop=True)

    print(table)
    print('-'*64)
# Out:
# Learning rate: 1e-05
#                Model Optimizer Epoch      Loss Accuracy (train)
# 0   FullyConnected_1       SGD     1  2.304428        13.358791
# 1   FullyConnected_1       SGD     2  2.304377        13.662287
# 2   FullyConnected_1       SGD     3  2.304326        14.020811
# 3   FullyConnected_1       SGD     4  2.304274         14.34932
# 4   FullyConnected_1       SGD     5  2.304222        14.634472
# 5   FullyConnected_1       SGD     6  2.304172        14.959645
# 6   FullyConnected_1       SGD     7   2.30412        15.281483
# 7   FullyConnected_1       SGD     8  2.304067        15.606657
# 8   FullyConnected_1       SGD     9  2.304015        15.970184
# 9   FullyConnected_1       SGD    10  2.303964         16.28702
# 10  FullyConnected_1      Adam     1  1.833833        72.271878
# 11  FullyConnected_1      Adam     2  1.675422        81.171625
# 12  FullyConnected_1      Adam     3  1.651961        82.774146
# 13  FullyConnected_1      Adam     4  1.638549        83.784685
# 14  FullyConnected_1      Adam     5  1.628628        84.665155
# 15  FullyConnected_1      Adam     6  1.620672        85.355523
# 16  FullyConnected_1      Adam     7  1.613495        86.032551
# 17  FullyConnected_1      Adam     8   1.60496        86.861326
# 18  FullyConnected_1      Adam     9  1.592787        88.133671
# 19  FullyConnected_1      Adam    10  1.583465         89.05583
# 20               ---       ---   ---       ---              ---
# 21   Convolutional_1       SGD     1  2.304621        12.276547
# 22   Convolutional_1       SGD     2  2.304596        12.383271
# 23   Convolutional_1       SGD     3  2.304571        12.473319
# 24   Convolutional_1       SGD     4  2.304548        12.553362
# 25   Convolutional_1       SGD     5  2.304524        12.638407
# 26   Convolutional_1       SGD     6  2.304499        12.700107
# 27   Convolutional_1       SGD     7  2.304475        12.783485
# 28   Convolutional_1       SGD     8  2.304451        12.848519
# 29   Convolutional_1       SGD     9  2.304426        12.921892
# 30   Convolutional_1       SGD    10  2.304402        13.010272
# 31   Convolutional_1      Adam     1  2.100512         54.15555
# 32   Convolutional_1      Adam     2  1.823992        72.458645
# 33   Convolutional_1      Adam     3   1.74785        76.284018
# 34   Convolutional_1      Adam     4  1.718583        77.871531
# 35   Convolutional_1      Adam     5  1.701768        78.753669
# 36   Convolutional_1      Adam     6  1.689977        79.517409
# 37   Convolutional_1      Adam     7  1.680788        80.189434
# 38   Convolutional_1      Adam     8  1.673889        80.683031
# 39   Convolutional_1      Adam     9  1.668306         81.03155
# 40   Convolutional_1      Adam    10  1.663523        81.441769
# 41               ---       ---   ---       ---              ---
# 42   Convolutional_3       SGD     1  2.305195        10.010339
# 43   Convolutional_3       SGD     2  2.305195        10.012006
# 44   Convolutional_3       SGD     3  2.305194        10.007004
# 45   Convolutional_3       SGD     4  2.305193        10.012006
# 46   Convolutional_3       SGD     5  2.305191        10.012006
# 47   Convolutional_3       SGD     6   2.30519        10.008671
# 48   Convolutional_3       SGD     7   2.30519        10.008671
# 49   Convolutional_3       SGD     8  2.305187        10.015342
# 50   Convolutional_3       SGD     9  2.305187        10.013674
# 51   Convolutional_3       SGD    10  2.305186        10.013674
# 52   Convolutional_3      Adam     1  2.136534        45.415888
# 53   Convolutional_3      Adam     2  1.847771        65.048026
# 54   Convolutional_3      Adam     3  1.799635        68.166355
# 55   Convolutional_3      Adam     4  1.779359        69.558765
# 56   Convolutional_3      Adam     5  1.767302         70.53095
# 57   Convolutional_3      Adam     6  1.758822        71.261339
# 58   Convolutional_3      Adam     7  1.752682        71.749933
# 59   Convolutional_3      Adam     8  1.747437        72.200173
# 60   Convolutional_3      Adam     9  1.743512        72.513674
# 61   Convolutional_3      Adam    10  1.739914         72.83051
# ----------------------------------------------------------------
#
# Learning rate: 0.0001
#                Model Optimizer Epoch      Loss Accuracy (train)
# 0   FullyConnected_1       SGD     1  2.304731         13.46218
# 1   FullyConnected_1       SGD     2  2.304247        13.897412
# 2   FullyConnected_1       SGD     3  2.303733        14.302628
# 3   FullyConnected_1       SGD     4  2.303185        14.719517
# 4   FullyConnected_1       SGD     5  2.302602           15.625
# 5   FullyConnected_1       SGD     6  2.301989        17.267543
# 6   FullyConnected_1       SGD     7  2.301352        19.293623
# 7   FullyConnected_1       SGD     8  2.300692        21.556497
# 8   FullyConnected_1       SGD     9  2.300008        23.797692
# 9   FullyConnected_1       SGD    10  2.299303        25.601988
# 10  FullyConnected_1      Adam     1  1.717226        75.898813
# 11  FullyConnected_1      Adam     2  1.590558        88.046958
# 12  FullyConnected_1      Adam     3  1.556705        91.183631
# 13  FullyConnected_1      Adam     4   1.53719        93.069637
# 14  FullyConnected_1      Adam     5  1.518469        94.923959
# 15  FullyConnected_1      Adam     6  1.492468        97.460312
# 16  FullyConnected_1      Adam     7  1.486038          98.0006
# 17  FullyConnected_1      Adam     8  1.482036         98.36913
# 18  FullyConnected_1      Adam     9  1.479907        98.575907
# 19  FullyConnected_1      Adam    10  1.477799        98.719317
# 20               ---       ---   ---       ---              ---
# 21   Convolutional_1       SGD     1   2.30383        12.735125
# 22   Convolutional_1       SGD     2  2.303431        13.572239
# 23   Convolutional_1       SGD     3  2.303029        14.642809
# 24   Convolutional_1       SGD     4  2.302618        15.933498
# 25   Convolutional_1       SGD     5  2.302202        17.422625
# 26   Convolutional_1       SGD     6  2.301776        19.181897
# 27   Convolutional_1       SGD     7  2.301343        21.011206
# 28   Convolutional_1       SGD     8  2.300902        22.913887
# 29   Convolutional_1       SGD     9  2.300447        24.748199
# 30   Convolutional_1       SGD    10  2.299989        26.420758
# 31   Convolutional_1      Adam     1   1.77687        72.723786
# 32   Convolutional_1      Adam     2  1.658068        81.703575
# 33   Convolutional_1      Adam     3  1.635753        83.651281
# 34   Convolutional_1      Adam     4  1.618649        85.313834
# 35   Convolutional_1      Adam     5  1.605466        86.581177
# 36   Convolutional_1      Adam     6  1.595007        87.578375
# 37   Convolutional_1      Adam     7  1.587245        88.293757
# 38   Convolutional_1      Adam     8  1.575446        89.477721
# 39   Convolutional_1      Adam     9  1.559502         91.13694
# 40   Convolutional_1      Adam    10  1.551578        91.868997
# 41               ---       ---   ---       ---              ---
# 42   Convolutional_3       SGD     1  2.305193        10.007004
# 43   Convolutional_3       SGD     2  2.305189        10.005336
# 44   Convolutional_3       SGD     3  2.305182        10.008671
# 45   Convolutional_3       SGD     4  2.305176        10.007004
# 46   Convolutional_3       SGD     5  2.305171        10.002001
# 47   Convolutional_3       SGD     6  2.305165        10.002001
# 48   Convolutional_3       SGD     7  2.305158         9.998666
# 49   Convolutional_3       SGD     8  2.305153        10.002001
# 50   Convolutional_3       SGD     9  2.305146        10.005336
# 51   Convolutional_3       SGD    10   2.30514        10.007004
# 52   Convolutional_3      Adam     1  1.932838         54.10052
# 53   Convolutional_3      Adam     2  1.840613        62.428295
# 54   Convolutional_3      Adam     3  1.782444        68.264741
# 55   Convolutional_3      Adam     4  1.753073        71.176294
# 56   Convolutional_3      Adam     5  1.688178         77.91322
# 57   Convolutional_3      Adam     6  1.639935        82.672425
# 58   Convolutional_3      Adam     7   1.56075        90.953509
# 59   Convolutional_3      Adam     8  1.516433        95.272479
# 60   Convolutional_3      Adam     9  1.505005        96.321371
# 61   Convolutional_3      Adam    10  1.497732        97.013407
# ----------------------------------------------------------------
#
# Learning rate: 0.001
#                Model Optimizer Epoch      Loss Accuracy (train)
# 0   FullyConnected_1       SGD     1  2.302409        20.976187
# 1   FullyConnected_1       SGD     2  2.296056        30.447906
# 2   FullyConnected_1       SGD     3  2.286871        31.139941
# 3   FullyConnected_1       SGD     4  2.273505        30.784752
# 4   FullyConnected_1       SGD     5  2.253197        29.657484
# 5   FullyConnected_1       SGD     6  2.225447        30.781417
# 6   FullyConnected_1       SGD     7  2.193791        33.107657
# 7   FullyConnected_1       SGD     8  2.161312        35.632337
# 8   FullyConnected_1       SGD     9  2.128931        39.089181
# 9   FullyConnected_1       SGD    10  2.095553        44.462046
# 10  FullyConnected_1      Adam     1  1.673777        78.942102
# 11  FullyConnected_1      Adam     2   1.58758        87.580043
# 12  FullyConnected_1      Adam     3  1.571827        89.162553
# 13  FullyConnected_1      Adam     4  1.563214        90.023012
# 14  FullyConnected_1      Adam     5  1.559291        90.421558
# 15  FullyConnected_1      Adam     6  1.562126        90.148079
# 16  FullyConnected_1      Adam     7  1.562269        90.126401
# 17  FullyConnected_1      Adam     8  1.565374        89.827908
# 18  FullyConnected_1      Adam     9  1.566005        89.756203
# 19  FullyConnected_1      Adam    10  1.561794        90.196438
# 20               ---       ---   ---       ---              ---
# 21   Convolutional_1       SGD     1   2.30381        16.657217
# 22   Convolutional_1       SGD     2  2.300899        24.276281
# 23   Convolutional_1       SGD     3  2.297501        34.546758
# 24   Convolutional_1       SGD     4  2.293296        39.937967
# 25   Convolutional_1       SGD     5  2.287794        41.748933
# 26   Convolutional_1       SGD     6   2.28013        41.852321
# 27   Convolutional_1       SGD     7  2.268132        41.722252
# 28   Convolutional_1       SGD     8  2.246954        40.376534
# 29   Convolutional_1       SGD     9  2.212949        41.575507
# 30   Convolutional_1       SGD    10  2.173142        46.611526
# 31   Convolutional_1      Adam     1  1.681792        78.701974
# 32   Convolutional_1      Adam     2  1.568064        89.841249
# 33   Convolutional_1      Adam     3  1.536822        92.914554
# 34   Convolutional_1      Adam     4  1.526604        93.855056
# 35   Convolutional_1      Adam     5  1.498064        96.728255
# 36   Convolutional_1      Adam     6  1.484916        98.003935
# 37   Convolutional_1      Adam     7  1.479062         98.59425
# 38   Convolutional_1      Adam     8  1.476241        98.871065
# 39   Convolutional_1      Adam     9  1.474228        99.016142
# 40   Convolutional_1      Adam    10   1.47242        99.206243
# 41               ---       ---   ---       ---              ---
# 42   Convolutional_3       SGD     1  2.304966         10.57564
# 43   Convolutional_3       SGD     2  2.304723        13.105323
# 44   Convolutional_3       SGD     3  2.304488        16.188634
# 45   Convolutional_3       SGD     4  2.304262        17.537687
# 46   Convolutional_3       SGD     5  2.304036        17.802828
# 47   Convolutional_3       SGD     6  2.303805        17.807831
# 48   Convolutional_3       SGD     7  2.303566        18.056297
# 49   Convolutional_3       SGD     8  2.303305        18.483191
# 50   Convolutional_3       SGD     9  2.303021        18.865061
# 51   Convolutional_3       SGD    10  2.302729        19.380336
# 52   Convolutional_3      Adam     1  1.657698         80.95651
# 53   Convolutional_3      Adam     2  1.542333        92.250867
# 54   Convolutional_3      Adam     3  1.529938        93.409819
# 55   Convolutional_3      Adam     4  1.524212        93.963447
# 56   Convolutional_3      Adam     5  1.515632         94.78722
# 57   Convolutional_3      Adam     6  1.490589        97.373599
# 58   Convolutional_3      Adam     7  1.481003        98.295758
# 59   Convolutional_3      Adam     8  1.478075        98.589248
# 60   Convolutional_3      Adam     9  1.477735        98.620931
# 61   Convolutional_3      Adam    10  1.476791        98.697639
# ----------------------------------------------------------------
#
# Learning rate: 0.01
#                Model Optimizer Epoch      Loss Accuracy (train)
# 0   FullyConnected_1       SGD     1  2.220485        28.740328
# 1   FullyConnected_1       SGD     2  1.948987        60.363861
# 2   FullyConnected_1       SGD     3  1.822333        68.933431
# 3   FullyConnected_1       SGD     4  1.785841        70.562633
# 4   FullyConnected_1       SGD     5  1.769212        71.473119
# 5   FullyConnected_1       SGD     6  1.749822        73.609258
# 6   FullyConnected_1       SGD     7  1.713198        77.984925
# 7   FullyConnected_1       SGD     8  1.689692        80.002668
# 8   FullyConnected_1       SGD     9  1.677372        80.819771
# 9   FullyConnected_1       SGD    10  1.668911         81.40008
# 10  FullyConnected_1      Adam     1  2.363758         9.995331
# 11  FullyConnected_1      Adam     2  2.363674        10.010339
# 12  FullyConnected_1      Adam     3  2.363691        10.008671
# 13  FullyConnected_1      Adam     4  2.363657        10.012006
# 14  FullyConnected_1      Adam     5  2.363674        10.010339
# 15  FullyConnected_1      Adam     6  2.363641        10.013674
# 16  FullyConnected_1      Adam     7  2.363724        10.005336
# 17  FullyConnected_1      Adam     8  2.363674        10.010339
# 18  FullyConnected_1      Adam     9  2.363624        10.015342
# 19  FullyConnected_1      Adam    10  2.363691        10.008671
# 20               ---       ---   ---       ---              ---
# 21   Convolutional_1       SGD     1   2.26942        31.421758
# 22   Convolutional_1       SGD     2  1.905468        64.494397
# 23   Convolutional_1       SGD     3  1.741458        75.235125
# 24   Convolutional_1       SGD     4  1.706807        77.651414
# 25   Convolutional_1       SGD     5  1.689303        78.888741
# 26   Convolutional_1       SGD     6   1.67869        79.677495
# 27   Convolutional_1       SGD     7  1.670623        80.337847
# 28   Convolutional_1       SGD     8  1.664532        80.834779
# 29   Convolutional_1       SGD     9  1.659395        81.266676
# 30   Convolutional_1       SGD    10  1.655261        81.666889
# 31   Convolutional_1      Adam     1  1.739296        72.246865
# 32   Convolutional_1      Adam     2  1.579225        88.450507
# 33   Convolutional_1      Adam     3  1.549509        91.402081
# 34   Convolutional_1      Adam     4  1.549434        91.423759
# 35   Convolutional_1      Adam     5  1.557719        90.593316
# 36   Convolutional_1      Adam     6  1.558302        90.544957
# 37   Convolutional_1      Adam     7  1.552584        91.115261
# 38   Convolutional_1      Adam     8  1.546008        91.777281
# 39   Convolutional_1      Adam     9  1.549657        91.403749
# 40   Convolutional_1      Adam    10  1.552873        91.086913
# 41               ---       ---   ---       ---              ---
# 42   Convolutional_3       SGD     1   2.30444          16.3754
# 43   Convolutional_3       SGD     2  2.303054         19.03682
# 44   Convolutional_3       SGD     3  2.300421        23.284085
# 45   Convolutional_3       SGD     4  2.289069         27.23119
# 46   Convolutional_3       SGD     5  2.123276        36.554496
# 47   Convolutional_3       SGD     6  1.846559        64.884605
# 48   Convolutional_3       SGD     7   1.78011        69.408685
# 49   Convolutional_3       SGD     8  1.763572        70.587647
# 50   Convolutional_3       SGD     9  1.752669        71.566502
# 51   Convolutional_3       SGD    10  1.742148        72.573706
# 52   Convolutional_3      Adam     1  2.085336        37.760139
# 53   Convolutional_3      Adam     2  2.345524         11.82464
# 54   Convolutional_3      Adam     3  2.363691        10.008671
# 55   Convolutional_3      Adam     4  2.363691        10.008671
# 56   Convolutional_3      Adam     5  2.363657        10.012006
# 57   Convolutional_3      Adam     6  2.363624        10.015342
# 58   Convolutional_3      Adam     7  2.363591        10.018677
# 59   Convolutional_3      Adam     8  2.363707        10.007004
# 60   Convolutional_3      Adam     9  2.363707        10.007004
# 61   Convolutional_3      Adam    10  2.363707        10.007004
# ----------------------------------------------------------------
#
# Learning rate: 0.1
#                Model Optimizer Epoch      Loss Accuracy (train)
# 0   FullyConnected_1       SGD     1  1.788553        71.303028
# 1   FullyConnected_1       SGD     2  1.651126        82.285552
# 2   FullyConnected_1       SGD     3  1.628218        84.291622
# 3   FullyConnected_1       SGD     4  1.613238        85.735726
# 4   FullyConnected_1       SGD     5  1.600115        87.036419
# 5   FullyConnected_1       SGD     6  1.580571        89.019144
# 6   FullyConnected_1       SGD     7  1.567282        90.329843
# 7   FullyConnected_1       SGD     8  1.557924         91.22532
# 8   FullyConnected_1       SGD     9  1.550634        91.882337
# 9   FullyConnected_1       SGD    10  1.544041        92.512673
# 10  FullyConnected_1      Adam     1  2.363724         9.995331
# 11  FullyConnected_1      Adam     2  2.363691        10.008671
# 12  FullyConnected_1      Adam     3  2.363657        10.012006
# 13  FullyConnected_1      Adam     4  2.363674        10.010339
# 14  FullyConnected_1      Adam     5  2.363674        10.010339
# 15  FullyConnected_1      Adam     6  2.363674        10.010339
# 16  FullyConnected_1      Adam     7  2.363691        10.008671
# 17  FullyConnected_1      Adam     8  2.363674        10.010339
# 18  FullyConnected_1      Adam     9  2.363674        10.010339
# 19  FullyConnected_1      Adam    10  2.363657        10.012006
# 20               ---       ---   ---       ---              ---
# 21   Convolutional_1       SGD     1  1.780205        71.703242
# 22   Convolutional_1       SGD     2  1.653721        81.441769
# 23   Convolutional_1       SGD     3  1.627116        83.986459
# 24   Convolutional_1       SGD     4  1.598645        86.918023
# 25   Convolutional_1       SGD     5  1.577139         89.05583
# 26   Convolutional_1       SGD     6   1.56427        90.361526
# 27   Convolutional_1       SGD     7  1.555434        91.193637
# 28   Convolutional_1       SGD     8  1.549215         91.74393
# 29   Convolutional_1       SGD     9  1.542979        92.375934
# 30   Convolutional_1       SGD    10  1.538484        92.819504
# 31   Convolutional_1      Adam     1  2.363638        10.002001
# 32   Convolutional_1      Adam     2  2.363657        10.012006
# 33   Convolutional_1      Adam     3  2.363724        10.005336
# 34   Convolutional_1      Adam     4  2.363674        10.010339
# 35   Convolutional_1      Adam     5  2.363591        10.018677
# 36   Convolutional_1      Adam     6  2.363691        10.008671
# 37   Convolutional_1      Adam     7  2.363674        10.010339
# 38   Convolutional_1      Adam     8  2.363691        10.008671
# 39   Convolutional_1      Adam     9  2.363707        10.007004
# 40   Convolutional_1      Adam    10  2.363691        10.008671
# 41               ---       ---   ---       ---              ---
# 42   Convolutional_3       SGD     1  2.106516        35.273813
# 43   Convolutional_3       SGD     2  1.758721        70.711046
# 44   Convolutional_3       SGD     3  1.672003        79.519077
# 45   Convolutional_3       SGD     4  1.596225        87.123132
# 46   Convolutional_3       SGD     5  1.571405        89.527748
# 47   Convolutional_3       SGD     6  1.546588        91.987393
# 48   Convolutional_3       SGD     7  1.536987        92.881203
# 49   Convolutional_3       SGD     8  1.531475        93.363127
# 50   Convolutional_3       SGD     9  1.527102        93.795024
# 51   Convolutional_3       SGD    10  1.524199         94.04349
# 52   Convolutional_3      Adam     1  2.363471        10.022012
# 53   Convolutional_3      Adam     2  2.363641        10.013674
# 54   Convolutional_3      Adam     3  2.363657        10.012006
# 55   Convolutional_3      Adam     4  2.363691        10.008671
# 56   Convolutional_3      Adam     5  2.363657        10.012006
# 57   Convolutional_3      Adam     6  2.363657        10.012006
# 58   Convolutional_3      Adam     7  2.363657        10.012006
# 59   Convolutional_3      Adam     8  2.363624        10.015342
# 60   Convolutional_3      Adam     9  2.363691        10.008671
# 61   Convolutional_3      Adam    10  2.363691        10.008671
# ----------------------------------------------------------------
#
# Learning rate: 0.5
#                Model Optimizer Epoch      Loss Accuracy (train)
# 0   FullyConnected_1       SGD     1  1.697356        77.421291
# 1   FullyConnected_1       SGD     2  1.595264        87.203175
# 2   FullyConnected_1       SGD     3  1.555656        91.160285
# 3   FullyConnected_1       SGD     4  1.539443        92.691102
# 4   FullyConnected_1       SGD     5  1.524574        94.166889
# 5   FullyConnected_1       SGD     6  1.515311        95.037353
# 6   FullyConnected_1       SGD     7  1.510154        95.489261
# 7   FullyConnected_1       SGD     8  1.506192        95.847785
# 8   FullyConnected_1       SGD     9  1.500587        96.391409
# 9   FullyConnected_1       SGD    10  1.477995        98.754336
# 10  FullyConnected_1      Adam     1  2.363622        10.010339
# 11  FullyConnected_1      Adam     2  2.363707        10.007004
# 12  FullyConnected_1      Adam     3  2.363707        10.007004
# 13  FullyConnected_1      Adam     4  2.363691        10.008671
# 14  FullyConnected_1      Adam     5  2.363674        10.010339
# 15  FullyConnected_1      Adam     6  2.363674        10.010339
# 16  FullyConnected_1      Adam     7  2.363641        10.013674
# 17  FullyConnected_1      Adam     8  2.363674        10.010339
# 18  FullyConnected_1      Adam     9  2.363707        10.007004
# 19  FullyConnected_1      Adam    10  2.363674        10.010339
# 20               ---       ---   ---       ---              ---
# 21   Convolutional_1       SGD     1  1.755433        71.291355
# 22   Convolutional_1       SGD     2  1.609817        85.767409
# 23   Convolutional_1       SGD     3  1.540013        92.596051
# 24   Convolutional_1       SGD     4  1.528847        93.633271
# 25   Convolutional_1       SGD     5  1.506797        95.894477
# 26   Convolutional_1       SGD     6  1.492901        97.265208
# 27   Convolutional_1       SGD     7   1.48954        97.532017
# 28   Convolutional_1       SGD     8  1.486528        97.805496
# 29   Convolutional_1       SGD     9  1.485102        97.953909
# 30   Convolutional_1       SGD    10   1.48251        98.209045
# 31   Convolutional_1      Adam     1  2.363671        10.010339
# 32   Convolutional_1      Adam     2  2.363641        10.013674
# 33   Convolutional_1      Adam     3  2.363691        10.008671
# 34   Convolutional_1      Adam     4  2.363641        10.013674
# 35   Convolutional_1      Adam     5  2.363674        10.010339
# 36   Convolutional_1      Adam     6  2.363674        10.010339
# 37   Convolutional_1      Adam     7  2.363657        10.012006
# 38   Convolutional_1      Adam     8  2.363674        10.010339
# 39   Convolutional_1      Adam     9  2.363724        10.005336
# 40   Convolutional_1      Adam    10  2.363657        10.012006
# 41               ---       ---   ---       ---              ---
# 42   Convolutional_3       SGD     1  1.769154        70.044023
# 43   Convolutional_3       SGD     2  1.564117        90.069704
# 44   Convolutional_3       SGD     3  1.533708        93.029616
# 45   Convolutional_3       SGD     4  1.519051        94.505403
# 46   Convolutional_3       SGD     5  1.497203        96.704909
# 47   Convolutional_3       SGD     6   1.48292        98.129002
# 48   Convolutional_3       SGD     7  1.479553        98.474186
# 49   Convolutional_3       SGD     8  1.476746        98.725987
# 50   Convolutional_3       SGD     9  1.476487        98.729322
# 51   Convolutional_3       SGD    10  1.474539        98.942769
# 52   Convolutional_3      Adam     1  2.363656         9.998666
# 53   Convolutional_3      Adam     2  2.363624        10.015342
# 54   Convolutional_3      Adam     3  2.363674        10.010339
# 55   Convolutional_3      Adam     4  2.363657        10.012006
# 56   Convolutional_3      Adam     5  2.363691        10.008671
# 57   Convolutional_3      Adam     6  2.363724        10.005336
# 58   Convolutional_3      Adam     7  2.363674        10.010339
# 59   Convolutional_3      Adam     8  2.363691        10.008671
# 60   Convolutional_3      Adam     9  2.363691        10.008671
# 61   Convolutional_3      Adam    10  2.363641        10.013674
# ----------------------------------------------------------------
#
# Learning rate: 1
#                Model Optimizer Epoch      Loss Accuracy (train)
# 0   FullyConnected_1       SGD     1   1.68675        77.883204
# 1   FullyConnected_1       SGD     2  1.582514        88.313767
# 2   FullyConnected_1       SGD     3  1.547439        91.768943
# 3   FullyConnected_1       SGD     4  1.528197          93.6883
# 4   FullyConnected_1       SGD     5  1.519086        94.588781
# 5   FullyConnected_1       SGD     6  1.499339        96.539821
# 6   FullyConnected_1       SGD     7  1.485302        97.957244
# 7   FullyConnected_1       SGD     8  1.481435        98.309098
# 8   FullyConnected_1       SGD     9  1.478389        98.619264
# 9   FullyConnected_1       SGD    10  1.476723        98.776014
# 10  FullyConnected_1      Adam     1  2.363755         9.995331
# 11  FullyConnected_1      Adam     2  2.363674        10.010339
# 12  FullyConnected_1      Adam     3  2.363607        10.017009
# 13  FullyConnected_1      Adam     4  2.363724        10.005336
# 14  FullyConnected_1      Adam     5  2.363641        10.013674
# 15  FullyConnected_1      Adam     6  2.363674        10.010339
# 16  FullyConnected_1      Adam     7  2.363707        10.007004
# 17  FullyConnected_1      Adam     8  2.363657        10.012006
# 18  FullyConnected_1      Adam     9  2.363691        10.008671
# 19  FullyConnected_1      Adam    10  2.363674        10.010339
# 20               ---       ---   ---       ---              ---
# 21   Convolutional_1       SGD     1  1.663371        80.264474
# 22   Convolutional_1       SGD     2  1.548776        91.677228
# 23   Convolutional_1       SGD     3  1.531189        93.341449
# 24   Convolutional_1       SGD     4  1.504195        96.029549
# 25   Convolutional_1       SGD     5  1.492927        97.158485
# 26   Convolutional_1       SGD     6  1.489826        97.435299
# 27   Convolutional_1       SGD     7  1.487196        97.698773
# 28   Convolutional_1       SGD     8  1.485502        97.865528
# 29   Convolutional_1       SGD     9  1.483975        97.998933
# 30   Convolutional_1       SGD    10  1.483522        98.043957
# 31   Convolutional_1      Adam     1  2.345028        11.862994
# 32   Convolutional_1      Adam     2  2.345031        11.874666
# 33   Convolutional_1      Adam     3  2.345031        11.874666
# 34   Convolutional_1      Adam     4  2.345031        11.874666
# 35   Convolutional_1      Adam     5  2.345031        11.874666
# 36   Convolutional_1      Adam     6  2.344981        11.879669
# 37   Convolutional_1      Adam     7  2.345031        11.874666
# 38   Convolutional_1      Adam     8  2.344997        11.878002
# 39   Convolutional_1      Adam     9  2.344981        11.879669
# 40   Convolutional_1      Adam    10  2.345048        11.872999
# 41               ---       ---   ---       ---              ---
# 42   Convolutional_3       SGD     1  1.717915        74.753202
# 43   Convolutional_3       SGD     2  1.550154        91.337046
# 44   Convolutional_3       SGD     3  1.537496        92.602721
# 45   Convolutional_3       SGD     4  1.534983         92.86953
# 46   Convolutional_3       SGD     5   1.53764        92.582711
# 47   Convolutional_3       SGD     6  1.546655        91.687233
# 48   Convolutional_3       SGD     7  1.583289        88.030283
# 49   Convolutional_3       SGD     8  2.055343        40.828442
# 50   Convolutional_3       SGD     9  2.362007        10.177094
# 51   Convolutional_3       SGD    10  2.362007        10.177094
# 52   Convolutional_3      Adam     1  2.363672        10.002001
# 53   Convolutional_3      Adam     2  2.363657        10.012006
# 54   Convolutional_3      Adam     3  2.363641        10.013674
# 55   Convolutional_3      Adam     4  2.363624        10.015342
# 56   Convolutional_3      Adam     5  2.363674        10.010339
# 57   Convolutional_3      Adam     6  2.363641        10.013674
# 58   Convolutional_3      Adam     7  2.363657        10.012006
# 59   Convolutional_3      Adam     8  2.363657        10.012006
# 60   Convolutional_3      Adam     9  2.363691        10.008671
# 61   Convolutional_3      Adam    10  2.363691        10.008671
# ----------------------------------------------------------------
#
# Learning rate: 3
#                Model Optimizer Epoch      Loss Accuracy (train)
# 0   FullyConnected_1       SGD     1  1.790122        67.155816
# 1   FullyConnected_1       SGD     2  1.721662        74.139541
# 2   FullyConnected_1       SGD     3  1.822497        64.102521
# 3   FullyConnected_1       SGD     4  1.930429        53.331777
# 4   FullyConnected_1       SGD     5  2.036394        42.737793
# 5   FullyConnected_1       SGD     6  2.082069         38.16869
# 6   FullyConnected_1       SGD     7  2.363391        10.038687
# 7   FullyConnected_1       SGD     8  2.363441        10.033685
# 8   FullyConnected_1       SGD     9  2.363441        10.033685
# 9   FullyConnected_1       SGD    10  2.363424        10.035352
# 10  FullyConnected_1      Adam     1  2.363689        10.000334
# 11  FullyConnected_1      Adam     2  2.363707        10.007004
# 12  FullyConnected_1      Adam     3  2.363674        10.010339
# 13  FullyConnected_1      Adam     4  2.363674        10.010339
# 14  FullyConnected_1      Adam     5  2.363641        10.013674
# 15  FullyConnected_1      Adam     6  2.363674        10.010339
# 16  FullyConnected_1      Adam     7  2.363641        10.013674
# 17  FullyConnected_1      Adam     8  2.363641        10.013674
# 18  FullyConnected_1      Adam     9  2.363641        10.013674
# 19  FullyConnected_1      Adam    10  2.363624        10.015342
# 20               ---       ---   ---       ---              ---
# 21   Convolutional_1       SGD     1  1.655308         80.71805
# 22   Convolutional_1       SGD     2  1.557702        90.548292
# 23   Convolutional_1       SGD     3   1.55673        90.681697
# 24   Convolutional_1       SGD     4  1.564878        89.871265
# 25   Convolutional_1       SGD     5  1.576603        88.717316
# 26   Convolutional_1       SGD     6  1.700011        76.369064
# 27   Convolutional_1       SGD     7  1.738835        72.491996
# 28   Convolutional_1       SGD     8   2.13607        32.769144
# 29   Convolutional_1       SGD     9  2.296065        16.770611
# 30   Convolutional_1       SGD    10  2.338144        12.563367
# 31   Convolutional_1      Adam     1  2.363673        10.000334
# 32   Convolutional_1      Adam     2  2.363707        10.007004
# 33   Convolutional_1      Adam     3  2.363657        10.012006
# 34   Convolutional_1      Adam     4  2.363707        10.007004
# 35   Convolutional_1      Adam     5  2.363674        10.010339
# 36   Convolutional_1      Adam     6  2.363724        10.005336
# 37   Convolutional_1      Adam     7  2.363674        10.010339
# 38   Convolutional_1      Adam     8  2.363624        10.015342
# 39   Convolutional_1      Adam     9  2.363657        10.012006
# 40   Convolutional_1      Adam    10  2.363641        10.013674
# 41               ---       ---   ---       ---              ---
# 42   Convolutional_3       SGD     1  2.314118        14.726187
# 43   Convolutional_3       SGD     2  2.343575        12.019744
# 44   Convolutional_3       SGD     3  2.363657        10.012006
# 45   Convolutional_3       SGD     4  2.363707        10.007004
# 46   Convolutional_3       SGD     5  2.363691        10.008671
# 47   Convolutional_3       SGD     6  2.363691        10.008671
# 48   Convolutional_3       SGD     7  2.363707        10.007004
# 49   Convolutional_3       SGD     8  2.363657        10.012006
# 50   Convolutional_3       SGD     9  2.363641        10.013674
# 51   Convolutional_3       SGD    10  2.363657        10.012006
# 52   Convolutional_3      Adam     1  2.363937          9.98199
# 53   Convolutional_3      Adam     2  2.363657        10.012006
# 54   Convolutional_3      Adam     3  2.363674        10.010339
# 55   Convolutional_3      Adam     4  2.363691        10.008671
# 56   Convolutional_3      Adam     5  2.363707        10.007004
# 57   Convolutional_3      Adam     6  2.363657        10.012006
# 58   Convolutional_3      Adam     7  2.363674        10.010339
# 59   Convolutional_3      Adam     8  2.363741        10.003669
# 60   Convolutional_3      Adam     9  2.363724        10.005336
# 61   Convolutional_3      Adam    10  2.363691        10.008671
# ----------------------------------------------------------------
#
# Learning rate: 5
#                Model Optimizer Epoch      Loss Accuracy (train)
# 0   FullyConnected_1       SGD     1  2.062729        39.907951
# 1   FullyConnected_1       SGD     2  2.354507        10.925827
# 2   FullyConnected_1       SGD     3  2.363524        10.025347
# 3   FullyConnected_1       SGD     4  2.363591        10.018677
# 4   FullyConnected_1       SGD     5  2.363591        10.018677
# 5   FullyConnected_1       SGD     6  2.363557        10.022012
# 6   FullyConnected_1       SGD     7  2.363557        10.022012
# 7   FullyConnected_1       SGD     8  2.363591        10.018677
# 8   FullyConnected_1       SGD     9  2.363607        10.017009
# 9   FullyConnected_1       SGD    10  2.363624        10.015342
# 10  FullyConnected_1      Adam     1  2.363621        10.008671
# 11  FullyConnected_1      Adam     2  2.363674        10.010339
# 12  FullyConnected_1      Adam     3  2.363724        10.005336
# 13  FullyConnected_1      Adam     4  2.363657        10.012006
# 14  FullyConnected_1      Adam     5  2.363724        10.005336
# 15  FullyConnected_1      Adam     6  2.363691        10.008671
# 16  FullyConnected_1      Adam     7  2.363707        10.007004
# 17  FullyConnected_1      Adam     8  2.363641        10.013674
# 18  FullyConnected_1      Adam     9  2.363674        10.010339
# 19  FullyConnected_1      Adam    10  2.363641        10.013674
# 20               ---       ---   ---       ---              ---
# 21   Convolutional_1       SGD     1  2.277368         18.51821
# 22   Convolutional_1       SGD     2  2.363674        10.010339
# 23   Convolutional_1       SGD     3  2.363707        10.007004
# 24   Convolutional_1       SGD     4  2.363674        10.010339
# 25   Convolutional_1       SGD     5  2.363707        10.007004
# 26   Convolutional_1       SGD     6  2.363657        10.012006
# 27   Convolutional_1       SGD     7  2.363674        10.010339
# 28   Convolutional_1       SGD     8  2.363707        10.007004
# 29   Convolutional_1       SGD     9  2.363657        10.012006
# 30   Convolutional_1       SGD    10  2.363641        10.013674
# 31   Convolutional_1      Adam     1  2.363588        10.015342
# 32   Convolutional_1      Adam     2  2.363641        10.013674
# 33   Convolutional_1      Adam     3  2.363724        10.005336
# 34   Convolutional_1      Adam     4  2.363657        10.012006
# 35   Convolutional_1      Adam     5  2.363707        10.007004
# 36   Convolutional_1      Adam     6  2.363674        10.010339
# 37   Convolutional_1      Adam     7  2.363674        10.010339
# 38   Convolutional_1      Adam     8  2.363691        10.008671
# 39   Convolutional_1      Adam     9  2.363691        10.008671
# 40   Convolutional_1      Adam    10  2.363674        10.010339
# 41               ---       ---   ---       ---              ---
# 42   Convolutional_3       SGD     1  2.358149         10.48726
# 43   Convolutional_3       SGD     2  2.363691        10.008671
# 44   Convolutional_3       SGD     3  2.363707        10.007004
# 45   Convolutional_3       SGD     4  2.363641        10.013674
# 46   Convolutional_3       SGD     5  2.363674        10.010339
# 47   Convolutional_3       SGD     6  2.363691        10.008671
# 48   Convolutional_3       SGD     7  2.363674        10.010339
# 49   Convolutional_3       SGD     8  2.363674        10.010339
# 50   Convolutional_3       SGD     9  2.363691        10.008671
# 51   Convolutional_3       SGD    10  2.363641        10.013674
# 52   Convolutional_3      Adam     1  2.363606        10.017009
# 53   Convolutional_3      Adam     2  2.363674        10.010339
# 54   Convolutional_3      Adam     3  2.363657        10.012006
# 55   Convolutional_3      Adam     4  2.363724        10.005336
# 56   Convolutional_3      Adam     5  2.363691        10.008671
# 57   Convolutional_3      Adam     6  2.363624        10.015342
# 58   Convolutional_3      Adam     7  2.363674        10.010339
# 59   Convolutional_3      Adam     8  2.363674        10.010339
# 60   Convolutional_3      Adam     9  2.363657        10.012006
# 61   Convolutional_3      Adam    10  2.363657        10.012006
# ----------------------------------------------------------------

# %% [markdown]
# #### Table summary
# - Learning rates >= 3 always produce bad results
# - All models w/ Adam and lr >= 0.1 are stuck on accuracy 10
# <br><br>
# Here are some relevant cases with respect to training accuracy
# - Adam w/ lr=0.001: Convolutional_3
# - SGD w/ lr=0.5: Convolutional_1
# - SGD w/ lr=1:   FullyConnected_1
# - Adam w/ lr=0.0001: FullyConnected_1
# - Adam w/ lr=0.001:  Convolutional_1

# %% [markdown]
# ## Plotting
# 4. For a model (not necessarily the best performing one), plot training loss vs testing loss and training accuracy vs testing accuracy, and comment on what you see.

# %% [markdown]
# We chose to take a look at the Convolutional_1 model with learning rate = 0.5 and SGD optimizer

# %%
# Shared parameters
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 10
learning_rate = 0.5
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# *Plotting training results*

# %%
model = Convolutional_1()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

print(f'Learning rate: {learning_rate}')
loss, accuracies, W_default = train_model(model, num_epochs, trainloader, criterion, optimizer, device)
# Out:
# Learning rate: 0.5
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/10] | Loss: 1.6977 | Train Accuracy: 76.9660 | Time: 8.66
# 	Epoch: [2/10] | Loss: 1.5779 | Train Accuracy: 88.9441 | Time: 7.55
# 	Epoch: [3/10] | Loss: 1.5387 | Train Accuracy: 92.7461 | Time: 8.36
# 	Epoch: [4/10] | Loss: 1.5255 | Train Accuracy: 94.0185 | Time: 8.30
# 	Epoch: [5/10] | Loss: 1.4976 | Train Accuracy: 96.8416 | Time: 7.59
# 	Epoch: [6/10] | Loss: 1.4919 | Train Accuracy: 97.3186 | Time: 8.36
# 	Epoch: [7/10] | Loss: 1.4892 | Train Accuracy: 97.5670 | Time: 8.35
# 	Epoch: [8/10] | Loss: 1.4868 | Train Accuracy: 97.7838 | Time: 7.50
# 	Epoch: [9/10] | Loss: 1.4852 | Train Accuracy: 97.9322 | Time: 8.35
# 	Epoch: [10/10] | Loss: 1.4840 | Train Accuracy: 98.0189 | Time: 8.28

# %%
print(accuracies)
print(loss)
# Out:
# [76.9660485592316, 88.94410352187833, 92.74613127001068, 94.0184765208111, 96.84164887940234, 97.31856990394877, 97.56703575240128, 97.78381803628602, 97.93223052294557, 98.01894343649947]
# [1.6977399208502428, 1.5779196093914476, 1.5386699361760436, 1.5255167133144025, 1.4976063962934365, 1.491936686580947, 1.489195944023743, 1.4868465641646655, 1.4851837798142, 1.4840022641032329]

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(range(1, num_epochs+1), accuracies)
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy (%)')
ax1.set_title('Training Accuracy')

ax2.plot(range(1, num_epochs+1), loss)
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.set_title('Training Loss')

plt.show()

# %% [markdown]
# *Plotting testing results*

# %%
def test_model(model):

    test_running_acc = 0.0
    test_running_loss = 0.0
    test_accuracy = []
    test_loss = []

    for i, (images, labels) in enumerate(testloader, 0):

        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)

        test_running_loss += loss.item()/(len(testloader) - 1)
        test_running_acc += get_accuracy(outputs, labels)/(len(testloader) - 1)

    test_accuracy += [test_running_acc]
    test_loss += [test_running_loss]

    print(f"Test Accuracy: {test_running_acc:.4f}")
    print(f"Test Loss: {test_running_loss:.4f}")

    return test_accuracy, test_loss

# %%
model = Convolutional_1()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

test_accuracy_list = []
test_loss_list = []

# This value sets the interval after which a test set evaluation is performed;
# for example, if epochs_interval = 2, the model is tested after every two training epochs
epochs_interval = 1

for i in range(int(num_epochs/epochs_interval)):

    _, _, _ = train_model(model, epochs_interval, trainloader, criterion, optimizer, device)
    print(f'Total epochs: [{(i+1)*epochs_interval}/{num_epochs}]')

    test_accuracy, test_loss = test_model(model)
    test_accuracy_list += [test_accuracy] * epochs_interval
    test_loss_list += [test_loss] * epochs_interval

    print('-'*90)
    print()
# Out:
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.7098 | Train Accuracy: 75.8555 | Time: 7.63
#
#
# Total epochs: [1/10]
# Test Accuracy: 72.8065
# Test Loss: 1.7518
# ------------------------------------------------------------------------------------------
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.5714 | Train Accuracy: 89.6261 | Time: 7.91
#
#
# Total epochs: [2/10]
# Test Accuracy: 81.1799
# Test Loss: 1.6681
# ------------------------------------------------------------------------------------------
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.5385 | Train Accuracy: 92.7511 | Time: 8.37
#
#
# Total epochs: [3/10]
# Test Accuracy: 83.1731
# Test Loss: 1.6471
# ------------------------------------------------------------------------------------------
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.5285 | Train Accuracy: 93.6600 | Time: 8.43
#
#
# Total epochs: [4/10]
# Test Accuracy: 84.8858
# Test Loss: 1.6296
# ------------------------------------------------------------------------------------------
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.5222 | Train Accuracy: 94.2786 | Time: 7.50
#
#
# Total epochs: [5/10]
# Test Accuracy: 85.3766
# Test Loss: 1.6229
# ------------------------------------------------------------------------------------------
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.5038 | Train Accuracy: 96.1396 | Time: 8.01
#
#
# Total epochs: [6/10]
# Test Accuracy: 91.0056
# Test Loss: 1.5686
# ------------------------------------------------------------------------------------------
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.4908 | Train Accuracy: 97.4136 | Time: 8.30
#
#
# Total epochs: [7/10]
# Test Accuracy: 91.4463
# Test Loss: 1.5660
# ------------------------------------------------------------------------------------------
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.4880 | Train Accuracy: 97.6604 | Time: 8.20
#
#
# Total epochs: [8/10]
# Test Accuracy: 92.2276
# Test Loss: 1.5566
# ------------------------------------------------------------------------------------------
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.4859 | Train Accuracy: 97.8622 | Time: 7.50
#
#
# Total epochs: [9/10]
# Test Accuracy: 91.4263
# Test Loss: 1.5640
# ------------------------------------------------------------------------------------------
#
# Training model: Convolutional_1 with Loss function: CrossEntropyLoss() and Optimizer: SGD
#
# 	Epoch: [1/1] | Loss: 1.4813 | Train Accuracy: 98.3475 | Time: 8.34
#
#
# Total epochs: [10/10]
# Test Accuracy: 93.9002
# Test Loss: 1.5401
# ------------------------------------------------------------------------------------------

# %%
print(test_accuracy_list)
print(test_loss_list)
# Out:
# [[72.80649038461543], [81.17988782051286], [83.1730769230769], [84.88581730769235], [85.37660256410254], [91.00560897435902], [91.44631410256414], [92.22756410256412], [91.42628205128207], [93.90024038461542]]
# [[1.7518230095887792], [1.6681431959836912], [1.6470789160483923], [1.6296185843455484], [1.6228661193297453], [1.5685725433704165], [1.5659726995688226], [1.5566418927449441], [1.5639906900051315], [1.5400649576615064]]

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(12, 6))
x_axis = len(test_accuracy_list)

ax1.plot(range(1, num_epochs+1), accuracies, label='Train accuracy')
ax1.plot(range(1, x_axis+1), test_accuracy_list, label='Test accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy (%)')
ax1.set_title('Accuracy')
ax1.legend()

ax2.plot(range(1, num_epochs+1), loss, label='Train loss')
ax2.plot(range(1, x_axis+1), test_loss_list, label='Test loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.set_title('Loss')
ax2.legend()

plt.show()
